# %% [markdown]
# # Alex's Scratchpad

# %% [markdown]
# ### Feature Engineering Notes
# * NLP on pet description (use given sentiment analysis first?)
# * Dog breed type categorizing
# * Pure vs mixed class
# * Breed encoding by # datapoints > threshold

# %%
import json
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LogisticRegression, LinearRegression, Lasso, Ridge, RidgeClassifierCV
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.metrics import make_scorer
from keras.models import Sequential
from keras.layers import Dense, Dropout
from sklearn.preprocessing import OneHotEncoder, StandardScaler, MinMaxScaler
from quadratic_weighted_kappa import quadratic_weighted_kappa
# Out:
# C:\Users\alexg\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
train = pd.read_csv('data_minus_images/train.csv')

# %%
train.head()
# Out:
#    Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  Color3  \
# 0     2       Nibble    3     299       0       1       1       7       0
# 1     2  No Name Yet    1     265       0       1       1       2       0
# 2     1       Brisco    1     307       0       1       2       7       0
# 3     1         Miko    4     307       0       2       1       2       0
# 4     1       Hunter    1     307       0       1       1       0       0
#
#    MaturitySize      ...        Health  Quantity  Fee  State  \
# 0             1      ...             1         1  100  41326
# 1             2      ...             1         1    0  41401
# 2             2      ...             1         1    0  41326
# 3             2      ...             1         1  150  41401
# 4             2      ...             1         1    0  41326
#
#                           RescuerID  VideoAmt  \
# 0  8480853f516546f6cf33aa88cd76c379         0
# 1  3082c7125d8fb66f7dd4bff4192c8b14         0
# 2  fa90fa5b1ee11c86938398b60abc32cb         0
# 3  9238e4f44c71a75282e62f7136c6b240         0
# 4  95481e953f8aed9ec3d16fc4509537e8         0
#
#                                          Description      PetID PhotoAmt  \
# 0  Nibble is a 3+ month old ball of cuteness. He ...  86e1089a3      1.0
# 1  I just found it alone yesterday near my apartm...  6296e909a      2.0
# 2  Their pregnant mother was dumped by her irresp...  3422e4906      7.0
# 3  Good guard dog, very alert, active, obedience ...  5842f1ff5      8.0
# 4  This handsome yet cute boy is up for adoption....  850a43f90      3.0
#
#    AdoptionSpeed
# 0              2
# 1              0
# 2              3
# 3              2
# 4              2
#
# [5 rows x 24 columns]

# %%
# Read sentiment file and extract score
def extract_sentiment(petID):
    try:
        with open('data_minus_images/train_sentiment/'+petID+'.json') as target:
            sentiment = json.load(target)
            magnitude, score = sentiment['documentSentiment'].values()
            language = sentiment['language']      
    except:
        magnitude, score, language = 0, 0, None
    return [magnitude, score, language]

# %%
extract_sentiment(train.iloc[0].PetID)
# Out:
# [2.4, 0.3, 'en']

# %%
def load_sentiments(pet_df):
    output = pet_df.set_index('PetID')
    output['magnitude'] = 0
    output['score'] = 0
    output['language'] = None
    for pet in output.index.values:
        sentiments = extract_sentiment(pet)
        output.loc[pet,['magnitude','score','language']] = sentiments
    return output.reset_index()

# %%
small_train = train.iloc[:100]
small_train
# Out:
#     Type                               Name  Age  Breed1  Breed2  Gender  \
# 0      2                             Nibble    3     299       0       1
# 1      2                        No Name Yet    1     265       0       1
# 2      1                             Brisco    1     307       0       1
# 3      1                               Miko    4     307       0       2
# 4      1                             Hunter    1     307       0       1
# 5      2                                NaN    3     266       0       2
# 6      2                              BULAT   12     264     264       1
# 7      1            Siu Pak & Her 6 Puppies    0     307       0       2
# 8      2                                NaN    2     265       0       2
# 9      2                              Kitty   12     265       0       2
# 10     1                               Bear    2     307       0       1
# 11     2                               Kali    3     264       0       2
# 12     1                             Peanut    2     307       0       1
# 13     2            2 Mths Old Cute Kitties    2     265       0       3
# 14     1                           Lost Dog    3     307       0       2
# 15     1                                Max   78     218     205       1
# 16     2                            Brownie    6     266       0       2
# 17     1                            Blackie    8     307     307       2
# 18     1                             Beauty    2     307       0       2
# 19     2                                NaN    1     266       0       3
# 20     1                             Godiva   12     307       0       2
# 21     1                             Tigers    3     307       0       2
# 22     2  Kenit, Kenot, Techit, Keyad, Owen    0     114       0       3
# 23     1                              Donut   10     307     117       2
# 24     2                            Cikenet    3     266       0       1
# 25     2                           Garfield   36     285     251       1
# 26     2                            No Name    2     285     265       1
# 27     2                            No Name    1     266       0       2
# 28     1                             Hunter   14     189       0       1
# 29     2                             Pepper    1     266       0       2
# ..   ...                                ...  ...     ...     ...     ...
# 70     1                               QiQi   36     307       0       2
# 71     1                                 H3    1     307     307       2
# 72     1                     Baby / Bubbles    2     141     128       1
# 73     1                              Ollie    2     307       0       1
# 74     1            9 Puppies For Adoption!    1     173      96       3
# 75     1                               Coco    2     307       0       2
# 76     1                   Pebbles & Pepper    2     307       0       2
# 77     1                                Zoe   12     307       0       2
# 78     1                                 Z3    2     307     307       1
# 79     1                                NaN    1     307       0       2
# 80     1                          MPSP-F-01    2     307       0       2
# 81     1                              Teddy    3     207       0       1
# 82     1                     Tanto In Kulim    3     307       0       1
# 83     1                               Cody    3     307     141       1
# 84     2                              Malee    6     265       0       2
# 85     1                        Mayo 2 Pups    1     307       0       2
# 86     2                               Lulu   47     250     285       2
# 87     1                   Rottweiler Puppy    2     189     307       1
# 88     1               Lion Dog In Training   12     307       0       2
# 89     1                              Molly    2     307      76       1
# 90     1                           Rocky 06    1     307       0       1
# 91     2                        Kiki & Lala    1     266     266       3
# 92     1                                NaN    1     307     307       3
# 93     2                          Si Kuning   24     266       0       1
# 94     2                         Xiao Huang   24     266       0       2
# 95     1                             HeiHei    2     307       0       1
# 96     2                              Manja   19     285       0       2
# 97     1                               Miko    4     207     169       2
# 98     1                           Fei Chai   24     307       0       1
# 99     2                                NaN    3     265       0       1
#
#     Color1  Color2  Color3  MaturitySize      ...        Health  Quantity  \
# 0        1       7       0             1      ...             1         1
# 1        1       2       0             2      ...             1         1
# 2        2       7       0             2      ...             1         1
# 3        1       2       0             2      ...             1         1
# 4        1       0       0             2      ...             1         1
# 5        5       6       0             2      ...             1         1
# 6        1       0       0             2      ...             1         1
# 7        1       2       7             2      ...             1         6
# 8        6       0       0             2      ...             1         1
# 9        1       7       0             2      ...             1         1
# 10       1       2       7             2      ...             1         1
# 11       1       2       5             3      ...             1         1
# 12       2       5       6             2      ...             1         1
# 13       1       6       7             1      ...             1         7
# 14       2       5       7             2      ...             1         1
# 15       1       7       0             2      ...             1         1
# 16       2       0       0             1      ...             1         1
# 17       2       0       0             2      ...             1         1
# 18       1       0       0             2      ...             1         1
# 19       1       2       7             1      ...             1         5
# 20       2       7       0             2      ...             1         1
# 21       6       0       0             2      ...             1         3
# 22       3       6       7             2      ...             1        10
# 23       1       2       7             2      ...             1         1
# 24       2       7       0             1      ...             1         1
# 25       3       0       0             3      ...             1         1
# 26       3       0       0             2      ...             1         1
# 27       1       0       0             2      ...             1         1
# 28       1       2       0             3      ...             1         1
# 29       2       7       0             1      ...             1         1
# ..     ...     ...     ...           ...      ...           ...       ...
# 70       1       2       0             2      ...             1         5
# 71       1       2       0             2      ...             1         1
# 72       1       2       7             1      ...             1         1
# 73       1       2       0             1      ...             1         1
# 74       1       2       7             2      ...             1         9
# 75       2       5       0             2      ...             1         1
# 76       1       0       0             3      ...             1         2
# 77       2       0       0             2      ...             1         1
# 78       2       0       0             2      ...             1         1
# 79       2       7       0             2      ...             1         1
# 80       1       2       0             2      ...             1         1
# 81       1       2       0             1      ...             1         1
# 82       1       7       0             2      ...             1         1
# 83       5       0       0             2      ...             1         1
# 84       5       7       0             2      ...             1         1
# 85       1       2       0             2      ...             1         2
# 26  healthy toilet trained cute easy to look after...  85fc3c314     11.0
# 27  Just saved this kitten from the street, but i ...  efbf1703a      2.0
# 28  healthy and active , skinny and tall, as the m...  7843a9dca      0.0
# 29  This kitten found at the roadside. Stay there ...  d341fbfd6      1.0
# ..                                                ...        ...      ...
# 70  I rescued QiQi with her sibling (Xiao Bai -) 3...  a9bc357f0      1.0
# 71                                     Dog 4 Adoption  aaf4a1439      1.0
# 72  3 month-old male puppy for adoption. a cross b...  1e62e6022      5.0
# 73  he's rescued from the industrial park. very ac...  4e797dcdd      3.0
# 74  I have two litters of puppies for adoption.. T...  45d2ddcb8      5.0
# 75  Hi Coco is a rescued puppy from the streets. I...  259b10a3e      1.0
# 76  These 2 beautiful puppies were left at the par...  d2490c888      3.0
# 77  Adopted her at a drive at Citta Mall when she ...  2c93c0c11      3.0
# 78                                       For Adoption  35593da00      5.0
# 79  This puppy is currently living in an abandoned...  4cc70e613      1.0
# 80  Puppy saved from MPSP pound yesterday. She is ...  ff125cf8d      1.0
# 81  he is the best breed of the so you can train h...  c30dd6e9a      2.0
# 82  Tanto needa a good home...he is a beautiful an...  be9474b85      1.0
# 83  Lovely puppy with good nature looking for a ho...  815f4cc08      3.0
# 84  Read story about Malee at She's very active,pl...  ec5069cf6      4.0
# 85  Very adorable and cute puppies Commitment to s...  867308404      3.0
# 86  I've had lulu since she was just a few weeks o...  e9df3ead7      2.0
# 87  We was found this dog from a roadside i think ...  258667857      4.0
# 88  Nickki is mixed breed,female, one year plus, f...  fd3172797     11.0
# 89  Mochi, momo and Molly are siblings, about 3 mo...  8df0bb3b3     18.0
# 90  Puppies are five week old and looking for good...  3d0752cd9      5.0
# 91  I rescuer them from road side, they both were ...  22051ab84      3.0
# 92  Mother and her puppies were found in Bayu Ting...  573b3ec3d      0.0
# 93  Saya jumpa kucing ini yang datang di rumah. Mu...  370fe2afb     12.0
# 94                        location: Klang contact no.  dd308e46b      1.0
# 95  HeiHei was picked up from Penang SPCA on 6th A...  6a763a055      2.0
# 96                                                NaN  5e4154870      3.0
# 97  very cute, obedient, friendly, playful and act...  a44d42407      3.0
# 98  Please adopt him!!! He need a home urgently. L...  cc8401c02      3.0
# 99                             owner desert them.....  0f24b6cd6      1.0
#
#     AdoptionSpeed
# 0               2
# 1               0
# 2               3
# 3               2
# 4               2
# 5               2
# 6               1
# 7               3
# 8               1
# 9               4
# 10              1
# 11              1
# 12              2
# 13              1
# 14              2
# 15              4
# 16              3
# 17              4
# 18              2
# 19              4
# 20              2
# 21              4
# 22              4
# 23              4
# 24              1
# 25              2
# 26              1
# 27              2
# 28              3
# 29              2
# ..            ...
# 70              4
# 71              3
# 72              1
# 73              4
# 74              2
# 75              0
# 76              4
# 77              3
# 78              1
# 79              3
# 80              4
# 81              1
# 82              2
# 83              3
# 84              3
# 85              2
# 86              4
# 87              2
# 88              3
# 89              3
# 90              3
# 91              4
# 92              4
# 93              3
# 94              4
# 95              3
# 96              1
# 97              3
# 98              3
# 99              1
#
# [100 rows x 24 columns]

# %%
test = load_sentiments(small_train)
test.head()
# Out:
#        PetID  Type         Name  Age  Breed1  Breed2  Gender  Color1  Color2  \
# 0  86e1089a3     2       Nibble    3     299       0       1       1       7
# 1  6296e909a     2  No Name Yet    1     265       0       1       1       2
# 2  3422e4906     1       Brisco    1     307       0       1       2       7
# 3  5842f1ff5     1         Miko    4     307       0       2       1       2
# 4  850a43f90     1       Hunter    1     307       0       1       1       0
#
#    Color3   ...     Fee  State                         RescuerID  VideoAmt  \
# 0       0   ...     100  41326  8480853f516546f6cf33aa88cd76c379         0
# 1       0   ...       0  41401  3082c7125d8fb66f7dd4bff4192c8b14         0
# 2       0   ...       0  41326  fa90fa5b1ee11c86938398b60abc32cb         0
# 3       0   ...     150  41401  9238e4f44c71a75282e62f7136c6b240         0
# 4       0   ...       0  41326  95481e953f8aed9ec3d16fc4509537e8         0
#
#                                          Description  PhotoAmt  AdoptionSpeed  \
# 0  Nibble is a 3+ month old ball of cuteness. He ...       1.0              2
# 1  I just found it alone yesterday near my apartm...       2.0              0
# 2  Their pregnant mother was dumped by her irresp...       7.0              3
# 3  Good guard dog, very alert, active, obedience ...       8.0              2
# 4  This handsome yet cute boy is up for adoption....       3.0              2
#
#    magnitude  score language
# 0        2.4    0.3       en
# 1        0.7   -0.2       en
# 2        3.7    0.2       en
# 3        0.9    0.9       en
# 4        3.7    0.6       en
#
# [5 rows x 27 columns]

# %% [markdown]
# ### Add Sentiments

# %%
add_sentiments = load_sentiments(train)

# %% [markdown]
# ### Add dog breed group, purebred label

# %%
breeds = pd.read_csv('data_minus_images/breed_labels.csv')

# %%
encoding = pd.read_csv('breed_group_encoding.csv', header=None,encoding = "ISO-8859-1")
encoding.set_index(0,inplace=True)
group_dict = encoding.to_dict()[1]

# %%
# Add breedname for group processing
add_breeds = pd.merge(add_sentiments,breeds.drop(columns=['Type']),left_on='Breed1',right_on='BreedID').drop(columns=['BreedID'])
# Preload with empty columns
add_breeds['BreedGroup'] = 'MISC'
add_breeds['BreedGroupID'] = 8

# %%
add_breeds.columns
# Out:
# Index(['PetID', 'Type', 'Name', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1',
#        'Color2', 'Color3', 'MaturitySize', 'FurLength', 'Vaccinated',
#        'Dewormed', 'Sterilized', 'Health', 'Quantity', 'Fee', 'State',
#        'RescuerID', 'VideoAmt', 'Description', 'PhotoAmt', 'AdoptionSpeed',
#        'magnitude', 'score', 'language', 'BreedName', 'BreedGroup',
#        'BreedGroupID'],
#       dtype='object')

# %%
group_ID=pd.DataFrame.from_dict({'MIXED':0,
                                  'HERDING':1,
                                  'HOUND':2,
                                  'TOY':3,
                                  'NON-SPORTING':4,
                                  'SPORTING':5,
                                  'TERRIER':6,
                                  'WORKING':7,
                                  'MISC':8,
                                  'FSS':9},orient='index',columns=['BreedID'])
group_ID
# Out:
#               BreedID
# MIXED               0
# HERDING             1
# HOUND               2
# TOY                 3
# NON-SPORTING        4
# SPORTING            5
# TERRIER             6
# WORKING             7
# MISC                8
# FSS                 9

# %%
# TODO: fix mixed breed label to account for multiple animals
def group_encoding(row):
    try:
        if row['Type']==2:
            row['BreedGroup']='CAT'
            row['BreedGroupID']=-1
        elif row['Breed1']==307 or row['Breed2']!=0:
            row['BreedGroup']='MIXED'
            row['BreedGroupID']=0
        else:
            group = group_dict[row['BreedName']]
            row['BreedGroup'] = group
            row['BreedGroupID'] = group_ID.loc[group].BreedID
    except:
        pass
    return row

# %%
add_groups = add_breeds.apply(group_encoding,axis=1)
# Add purebred flag
add_groups['purebred']=~((add_groups['BreedGroup']=='MIXED')|(add_groups['Breed2']!=0))*1

# %% [markdown]
# ### Add Description Length

# %%
add_groups['desc_len'] = add_groups['Description'].apply(lambda x: len(str(x)))
add_groups['start_cap'] = add_groups['Description'].apply(lambda x: 1*(str(x)[0]!=str(x)[0].lower()))
add_groups[['Description','desc_len','start_cap']]
# Out:
#                                              Description  desc_len  start_cap
# 0      Nibble is a 3+ month old ball of cuteness. He ...       359          1
# 1               Manja, comel ,dan memahami perasaan org.        40          1
# 2      This tabby was found by the clinic, has been s...       707          1
# 3      Found her when she's just about a weeks old at...       130          1
# 4      My cat's offspring Cham is lively and loves pl...        99          1
# 5      Looking for a playful, caring and affectionate...       869          1
# 6      Ashley and Ginger have been left to fend for t...       587          1
# 7      rescued a kitten at housing area. we are unabl...       144          0
# 8      Milk Milk & Mio Mio are cheerful kitten.They w...       163          1
# 9      KaKa is one of the 3 siblings with ChaoChao & ...       408          1
# 10     Simba is a 1 year old friendly male tabby. He ...      1078          1
# 11     Found them both in the middle of the road. The...       180          1
# 12            It was given birth by my pet cat in March.        42          1
# 13     Cobey was rescued from the drain at the tender...       110          1
# 14     Mouse is a very tame cat. He now lives in a co...       292          1
# 15     A total of 5 beautiful Tabbys available for ad...       304          1
# 16     very obedient, tahu nama dia, manja, get along...       383          0
# 17     found this little girl at Kajang town, almost ...       171          0
# 18     Meet Munchkin. Found all alone in this world b...       263          1
# 19     She is a very manja cat and do love attention....       571          1
# 20     Vodka is an adorable cat, great with human, an...        58          1
# 21     Peanut was rescued when he was about 2 months ...       346          1
# 22     I rescued Musang from a drain, he need a home....        94          1
# 23     Two love cats, is some ways husband and wife. ...       359          1
# 24        Looking for new home.healthy and litter train.        46          1
# 25     3 orange kitten (2 plain & 1 wif sum spots str...       360          0
# 26     Kittens up for adoption. Age 2 months old. Pot...       172          1
# 27     I found this cat crying outside my house in th...       546          1
# 28     LULU is a very cute cat but pretty shy and afr...       191          1
# 29     Felix was dumped in front of my office in KD f...       326          1
# ...                                                  ...       ...        ...
# 14958  she's a papillon mix maltese. she's very lovin...       300          0
# 14959  when i was walking back home after work at chi...       841          0
# 14960  4 of them have extra toes (as their mother's)....       818          0
# 14961  Luna was rescued from the undercarriage of a c...       786          1
# 14962  Roddy was found at shops in Ara Damansara. We ...       382          1
# 14963  Both adopted turned out to be boys so named To...       502          1
# 14964  Benjie was found loitering at my porch gate 10...       990          1
# 14965  Lovely puppy looking for a forever home. If u ...        88          1
# 14966  I found them yesterday at Lekas highway beside...       412          1
# 14967  I found them yesterday at Lekas highway beside...       412          1
# 14968  Missha is looking for a forever home. If u are...        83          1
# 14969  I am an owner of 2 dogs (Japanese Mixed Spitz)...       683          1
# 14970  She is just a stray.. Anyone who love cat can ...       541          1
# 14971  i have a very cute local dog . i am looking fo...       135          0
# 14972  This is a good dog. She needs a good home. Onl...        65          1
# 14973  This is a good dog. Only serious and genuine d...       100          1
# 14974  PLayful Young Kittens for adoption. Active and...        64          1
# 14975  Round, cute, playful and friendly. Come view M...       203          1
# 14976                         kiara love to eat and play        26          0
# 14977  Found a group of 7 motherless pups in Hulu Lan...        81          1
# 14978  2 years old mixed terrier welsh corgi waiting ...       209          0
# 14979  Hello People! My name is Princess. Princess in...       600          1
# 14980  I am cute, energetic swedish lapphud mix dog y...       729          1
# 14981                    Dec/ Adopted, Kuala Lumpur area        31          1
# 14982  hi... helping my fren to find adopter to his p...       187          0
# 14983  Kitty is a mixed breed beautiful female cat. K...       339          1
# 14984  Are you ready for the cat-parrot? I found Wonk...      1967          1
# 14985  i have a very cute local dog . i am looking fo...       135          0
# 14986  this dog belongs to my neighbor. My neighbor d...       327          0
# 14987  This cute little puppy was rescued by my neigh...       620          1
#
# [14988 rows x 3 columns]

# %% [markdown]
# ### Add Color Count, Name Flag

# %%
add_groups['num_colors']=1*(add_groups['Color1']>0)+1*(add_groups['Color2']>0)+1*(add_groups['Color3']>0)
add_groups['has_name']=~pd.isnull(add_groups['Name'])*1

# %% [markdown]
# ### Dummify categoricals

# %%
dummify = [
    'Gender'
    ,'Type'
]
add_groups.columns
# Out:
# Index(['PetID', 'Type', 'Name', 'Age', 'Breed1', 'Breed2', 'Gender', 'Color1',
#        'Color2', 'Color3', 'MaturitySize', 'FurLength', 'Vaccinated',
#        'Dewormed', 'Sterilized', 'Health', 'Quantity', 'Fee', 'State',
#        'RescuerID', 'VideoAmt', 'Description', 'PhotoAmt', 'AdoptionSpeed',
#        'magnitude', 'score', 'language', 'BreedName', 'BreedGroup',
#        'BreedGroupID', 'purebred', 'desc_len', 'start_cap', 'num_colors',
#        'has_name'],
#       dtype='object')

# %%
dummies = pd.get_dummies(add_groups[dummify],columns=dummify)
add_dummies = pd.concat([add_groups,dummies],axis=1)

# %% [markdown]
# ### Drop Columns and Fit Models

# %%
model_train = add_dummies
model_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14988 entries, 0 to 14987
# Data columns (total 40 columns):
# PetID            14988 non-null object
# Type             14988 non-null int64
# Name             13732 non-null object
# Age              14988 non-null int64
# Breed1           14988 non-null int64
# Breed2           14988 non-null int64
# Gender           14988 non-null int64
# Color1           14988 non-null int64
# Color2           14988 non-null int64
# Color3           14988 non-null int64
# MaturitySize     14988 non-null int64
# FurLength        14988 non-null int64
# Vaccinated       14988 non-null int64
# Dewormed         14988 non-null int64
# Sterilized       14988 non-null int64
# Health           14988 non-null int64
# Quantity         14988 non-null int64
# Fee              14988 non-null int64
# State            14988 non-null int64
# RescuerID        14988 non-null object
# VideoAmt         14988 non-null int64
# Description      14976 non-null object
# PhotoAmt         14988 non-null float64
# AdoptionSpeed    14988 non-null int64
# magnitude        14988 non-null float64
# score            14988 non-null float64
# language         14199 non-null object
# BreedName        14988 non-null object
# BreedGroup       14988 non-null object
# BreedGroupID     14988 non-null int64
# purebred         14988 non-null int32
# desc_len         14988 non-null int64
# start_cap        14988 non-null int64
# num_colors       14988 non-null int32
# has_name         14988 non-null int32
# Gender_1         14988 non-null uint8
# Gender_2         14988 non-null uint8
# Gender_3         14988 non-null uint8
# Type_1           14988 non-null uint8
# Type_2           14988 non-null uint8
# dtypes: float64(3), int32(3), int64(22), object(7), uint8(5)
# memory usage: 4.0+ MB

# %%
seed = 10
drop_columns = [
                'Name'
                ,'Breed1'
                ,'Breed2'
                ,'RescuerID'
                ,'Description'
                ,'PetID'
                ,'AdoptionSpeed'
                ,'language'
                ,'BreedGroup'
                ,'BreedName'
                ,'Color1'
                ,'Color2'
                ,'Color3'
                ,'State'
               ]
target = 'AdoptionSpeed' 
X = model_train.drop(columns=drop_columns+dummify)
y = model_train[target].astype('str')

sclr = StandardScaler()
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=seed)
X_train = sclr.fit_transform(X_train)
X_val = sclr.transform(X_val)
# Out:
# C:\Users\alexg\Anaconda3\lib\site-packages\sklearn\preprocessing\data.py:625: DataConversionWarning: Data with input dtype uint8, int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# C:\Users\alexg\Anaconda3\lib\site-packages\sklearn\base.py:462: DataConversionWarning: Data with input dtype uint8, int32, int64, float64 were all converted to float64 by StandardScaler.
#   return self.fit(X, **fit_params).transform(X)
# C:\Users\alexg\Anaconda3\lib\site-packages\ipykernel_launcher.py:25: DataConversionWarning: Data with input dtype uint8, int32, int64, float64 were all converted to float64 by StandardScaler.

# %%
def quadratic_weighted_kappa_scorer(estimator, X, y):
    pred_class = np.argmax(estimator.predict(X),axis=1)
    y_class = np.argmax(y,axis=1)
    score = quadratic_weighted_kappa(pred_class,y_class,min_rating=0,max_rating=4)
    return score

# %%
log = LogisticRegression(multi_class='ovr')
log.fit(X_train, y_train)
log_pred = log.predict(X_val)

ridge_cv = RidgeClassifierCV(alphas=(0.1,.5,1,2,5,10),scoring=quadratic_weighted_kappa_scorer, cv=10)
ridge_cv.fit(X_train, y_train)
ridge_pred = ridge_cv.predict(X_val)
# Out:
# C:\Users\alexg\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)

# %%
gbc = GradientBoostingClassifier(subsample=0.9, max_features=X_train.shape[1]//3, random_state=seed, verbose=1,learning_rate=0.1, n_estimators=100, max_leaf_nodes=1000, min_samples_split=5)
gbc.fit(X_train, y_train)
gbc_pred = gbc.predict(X_val)
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1       16628.4170          33.8151            8.78s
#          2       16359.6968          26.9287            7.55s
#          3       16119.0103          24.5354            8.68s
#          4       15919.4016          19.9505            8.68s
#          5       15732.6781          19.2223            9.96s
#          6       15566.3465          17.0646            9.53s
#          7       15423.3063          11.5131            9.63s
#          8       15289.4637          11.5905           10.19s
#          9       15192.3989          10.6279           10.33s
#         10       15087.4590           8.5543           10.17s
#         20       14410.3009           2.5288            7.67s
#         30       14129.3355           0.7426            6.76s
#         40       13864.3072          -0.5806            5.83s
#         50       13670.0951          -0.6643            4.88s
#         60       13494.7569           0.1713            3.96s
#         70       13321.3286          -0.7987            2.91s
#         80       13227.0716          -0.3678            1.92s
#         90       13087.1324          -1.1580            0.93s
#        100       12976.0367          -0.4971            0.00s

# %%
print(quadratic_weighted_kappa(log_pred,y_val))
print(quadratic_weighted_kappa(ridge_pred,y_val))
print(quadratic_weighted_kappa(gbc_pred,y_val))
# Out:
# 0.21047077500935585
# 0.20115001207557204
# 0.3091648917675981

# %%
gbc_pred
# Out:
# array(['1', '4', '1', ..., '4', '4', '4'], dtype=object)

# %% [markdown]
# ### Gradient Boosting hyperparameter tuning

# %% [markdown]
# Workflow notes:
# * Define starting parameters: high learning rate (default = 0.1 is fine) and tree params
# * Tune number of trees (trade-off with learning rate)
# * Tune tree parameters

# %%
# Starting params
learning_rate = 0.1 # default
min_samples_split = int(X_train.shape[0]//100)
min_samples_leaf = int(min_samples_split//10)
max_depth = 5 # small sample size
max_features = 'sqrt'
subsample=0.8
first_gbc = GradientBoostingClassifier(min_samples_split=min_samples_split,
                                       min_samples_leaf=min_samples_leaf,
                                       max_depth=max_depth,
                                       max_features=max_features,
                                       subsample=subsample,
                                       random_state=seed)

# %%
def quadratic_weighted_kappa_gbc_scorer(estimator, X, y):
    pred_class = estimator.predict(X)
    y_class = y
    score = quadratic_weighted_kappa(pred_class,y_class,min_rating=0,max_rating=4)
    return score

# %%
trees = {'n_estimators':range(20,81,10)}#[20,30,40,50,60,70,80]}
GSCV_1 = GridSearchCV(estimator = first_gbc,
                      param_grid = trees,
                      scoring=quadratic_weighted_kappa_gbc_scorer,
                      n_jobs=-1, iid=False, cv=5, verbose=1)
GSCV_1.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 7 candidates, totalling 35 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  35 out of  35 | elapsed:   49.9s finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=GradientBoostingClassifier(criterion='friedman_mse', init=None,
#               learning_rate=0.1, loss='deviance', max_depth=5,
#               max_features='sqrt', max_leaf_nodes=None,
#               min_impurity_decrease=0.0, min_impurity_split=None,
#               min_samples_leaf=11, min_sa...      subsample=0.8, tol=0.0001, validation_fraction=0.1,
#               verbose=0, warm_start=False),
#        fit_params=None, iid=False, n_jobs=-1,
#        param_grid={'n_estimators': range(20, 81, 10)},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=<function quadratic_weighted_kappa_gbc_scorer at 0x000001BF09AE8620>,
#        verbose=1)

# %%
# Optimal tree count:
GSCV_1.best_params_, GSCV_1.best_score_
# Out:
# ({'n_estimators': 80}, 0.32883233131970924)

# %%
n_estimators = GSCV_1.best_params_['n_estimators']
forest_sizes = {'max_depth':range(5,16,2),
                'min_samples_split':range(200,1001,200)}
second_gbc = GradientBoostingClassifier(min_samples_split=min_samples_split,
                                       min_samples_leaf=min_samples_leaf,
                                       n_estimators=n_estimators,
                                       max_depth=max_depth,
                                       max_features=max_features,
                                       subsample=subsample,
                                       random_state=seed)
GSCV_2 = GridSearchCV(estimator = second_gbc,
                      param_grid = forest_sizes,
                      scoring=quadratic_weighted_kappa_gbc_scorer,
                      n_jobs=-1, iid=False, cv=5, verbose=1)
GSCV_2.fit(X_train,y_train)
GSCV_2.best_params_, GSCV_2.best_score_
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 150 out of 150 | elapsed:  6.6min finished
# ({'max_depth': 11, 'min_samples_split': 600}, 0.3358124253432269)

# %%
# Tune features and leaf_sizes
max_depth, min_samples_split = GSCV_2.best_params_.values()
tree_params = {'max_features':range(7,20,4),'min_samples_leaf':range(30,71,10)}
last_gbc = GradientBoostingClassifier(min_samples_split=min_samples_split,
                                       n_estimators=n_estimators,
                                       max_depth=max_depth,
                                       subsample=subsample,
                                       random_state=seed)
GSCV_3 = GridSearchCV(estimator = last_gbc,
                      param_grid = tree_params,
                      scoring=quadratic_weighted_kappa_gbc_scorer,
                      n_jobs=-1, iid=False, cv=5, verbose=1)
GSCV_3.fit(X_train,y_train)
GSCV_3.best_params_, GSCV_3.best_score_
# Out:
# Fitting 5 folds for each of 20 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed:  3.0min
# [Parallel(n_jobs=-1)]: Done 100 out of 100 | elapsed:  9.0min finished
# ({'max_features': 11, 'min_samples_leaf': 40}, 0.33720269988507134)

# %%
max_features, min_samples_leaf = GSCV_3.best_params_.values()
